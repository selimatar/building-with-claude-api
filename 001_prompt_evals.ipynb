# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
import json

def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
def run_prompt(test_case):
    """Merges the prompt and test case input, then returns the result"""
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""
    
    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)
    
    # TODO - Grading
    score = 10
    
    return {
        "output": output,
        "test_case": test_case,
        "score": score
    }

# %%
def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    return results

# %%
with open("propmt_eval_dataset.json") as file:
    dataset = json.load(file)

results = run_eval(dataset)

# %%
print(json.dumps(results, indent=3))
# Out:
# [
#    {
#       "output": "# AWS S3 URI Parser\n\nHere's a Python function that parses AWS S3 bucket URIs:\n\n```python\ndef parse_s3_uri(uri):\n    \"\"\"\n    Parses an AWS S3 bucket URI and returns a dictionary with bucket and key.\n    \n    Args:\n        uri (str): An S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: A dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \n    Examples:\n        >>> parse_s3_uri('s3://my-bucket/path/to/file.txt')\n        {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n        \n        >>> parse_s3_uri('s3://my-bucket/')\n        {'bucket': 'my-bucket', 'key': ''}\n        \n        >>> parse_s3_uri('s3://my-bucket')\n        {'bucket': 'my-bucket', 'key': ''}\n    \"\"\"\n    # Check if the URI starts with 's3://'\n    if not uri.startswith('s3://'):\n        raise ValueError(f\"Invalid S3 URI: {uri}. URI must start with 's3://'\")\n    \n    # Remove the 's3://' prefix\n    uri_without_scheme = uri[5:]\n    \n    # Split by the first '/' to separate bucket and key\n    if '/' in uri_without_scheme:\n        bucket, key = uri_without_scheme.split('/', 1)\n    else:\n        bucket = uri_without_scheme\n        key = ''\n    \n    # Validate bucket name is not empty\n    if not bucket:\n        raise ValueError(f\"Invalid S3 URI: {uri}. Bucket name cannot be empty\")\n    \n    return {'bucket': bucket, 'key': key}\n```\n\n## Usage Examples\n\n```python\n# Basic usage\nprint(parse_s3_uri('s3://my-bucket/path/to/file.txt'))\n# Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n\n# With trailing slash\nprint(parse_s3_uri('s3://my-bucket/'))\n# Output: {'bucket': 'my-bucket', 'key': ''}\n\n# Without path\nprint(parse_s3_uri('s3://my-bucket'))\n# Output: {'bucket': 'my-bucket', 'key': ''}\n\n# Complex path\nprint(parse_s3_uri('s3://my-bucket/folder/subfolder/document.pdf'))\n# Output: {'bucket': 'my-bucket', 'key': 'folder/subfolder/document.pdf'}\n```\n\n## Alternative Implementation using urllib\n\nIf you prefer a more robust solution using Python's `urllib` library:\n\n```python\nfrom urllib.parse import urlparse\n\ndef parse_s3_uri_urllib(uri):\n    \"\"\"\n    Parses an AWS S3 bucket URI using urllib.\n    \n    Args:\n        uri (str): An S3 URI in the format 's3://bucket-name/path/to/file'\n    \n    Returns:\n        dict: A dictionary with 'bucket' and 'key' keys\n    \n    Raises:\n        ValueError: If the URI format is invalid\n    \"\"\"\n    parsed = urlparse(uri)\n    \n    if parsed.scheme != 's3':\n        raise ValueError(f\"Invalid S3 URI: {uri}. URI must start with 's3://'\")\n    \n    bucket = parsed.netloc\n    key = parsed.path.lstrip('/')  # Remove leading slash\n    \n    if not bucket:\n        raise ValueError(f\"Invalid S3 URI: {uri}. Bucket name cannot be empty\")\n    \n    return {'bucket': bucket, 'key': key}\n\n# Usage\nprint(parse_s3_uri_urllib('s3://my-bucket/path/to/file.txt'))\n# Output: {'bucket': 'my-bucket', 'key': 'path/to/file.txt'}\n```",
#       "test_case": {
#          "task": "Write a Python function that parses an AWS S3 bucket URI (e.g., 's3://my-bucket/path/to/file.txt') and returns a dictionary with keys 'bucket' and 'key'."
#       },
#       "score": 10
#    },
#    {
#       "output": "# AWS IAM Read-Only S3 Bucket Policy\n\nHere's a JSON object that creates a read-only access policy for the S3 bucket 'my-data-bucket':\n\n```json\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Sid\": \"ListBucket\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetBucketLocation\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket\"\n    },\n    {\n      \"Sid\": \"GetObject\",\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:GetObjectVersion\"\n      ],\n      \"Resource\": \"arn:aws:s3:::my-data-bucket/*\"\n    }\n  ]\n}\n```\n\n## Policy Breakdown\n\n| Action | Purpose |\n|--------|---------|\n| `s3:ListBucket` | Lists the contents of the bucket |\n| `s3:GetBucketLocation` | Retrieves bucket region information |\n| `s3:GetObject` | Reads/downloads objects from the bucket |\n| `s3:GetObjectVersion` | Accesses previous versions of objects (if versioning is enabled) |\n\n## Key Points\n\n- **Version**: Uses the standard IAM policy language version (2012-10-17)\n- **Effect**: Set to \"Allow\" to grant permissions\n- **Resources**: \n  - Bucket-level ARN: `arn:aws:s3:::my-data-bucket`\n  - Object-level ARN: `arn:aws:s3:::my-data-bucket/*`\n- **Read-Only**: No write, delete, or configuration permissions included",
#       "test_case": {
#          "task": "Create a JSON object that represents an AWS IAM policy allowing read-only access to a specific S3 bucket named 'my-data-bucket'."
#       },
#       "score": 10
#    },
#    {
#       "output": "# AWS EC2 Instance ID Regular Expression\n\nHere's a regular expression that matches valid AWS EC2 instance IDs:\n\n```regex\n^i-[0-9a-f]{17}$\n```\n\n## Breakdown\n\n| Component | Purpose |\n|-----------|---------|\n| `^` | Start of string anchor |\n| `i-` | Literal prefix (required for all EC2 instance IDs) |\n| `[0-9a-f]` | Character class matching hexadecimal digits (0-9 and a-f) |\n| `{17}` | Exactly 17 hexadecimal characters |\n| `$` | End of string anchor |\n\n## Examples\n\n### Valid Matches\n```\ni-0abcd1234efgh5678\ni-1234567890abcdef0\ni-ffffffffffffffff\n```\n\n### Invalid (No Match)\n```\ni-0abcd1234efgh567     # Only 16 characters\ni-0abcd1234efgh56789   # 18 characters (too long)\ni-0ABCD1234EFGH5678    # Uppercase (if case-sensitive)\n0abcd1234efgh5678      # Missing 'i-' prefix\n```\n\n## Implementation Examples\n\n**Python:**\n```python\nimport re\npattern = r'^i-[0-9a-f]{17}$'\nif re.match(pattern, instance_id):\n    print(\"Valid EC2 Instance ID\")\n```\n\n**JavaScript:**\n```javascript\nconst pattern = /^i-[0-9a-f]{17}$/;\nif (pattern.test(instanceId)) {\n    console.log(\"Valid EC2 Instance ID\");\n}\n```\n\n**Case-Insensitive Variant** (if needed):\n```regex\n^i-[0-9a-fA-F]{17}$\n```",
#       "test_case": {
#          "task": "Write a regular expression that matches valid AWS EC2 instance IDs (format: i- followed by 17 hexadecimal characters, e.g., i-0abcd1234efgh5678)."
#       },
#       "score": 10
#    }
# ]
