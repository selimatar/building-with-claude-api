# %%
# installing dependencies
#%pip install anthropic python-dotenv

# %%
# loading environment variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic
client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return message.content[0].text

# %%
# # Start with an empty message list
# messages = []

# # Add the initial user question
# add_user_message(messages, "What is quantum computing? Answer in one sentence")

# # Get Claude's response
# answer = chat(messages)

# # Add Claude's response to the conversation history
# add_assistant_message(messages, answer)

# # Add a follow-up question
# add_user_message(messages, "Can you explain it in more detail?")

# # Get the follow-up response with full context
# final_answer = chat(messages)

# %%
# Start with an empty message list
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    user_input = input("> ")
    print(">", user_input)

# Add user input to the list of messages
    add_user_message(messages, user_input)

# Call Claude with the 'chat' function
    answer = chat(messages)

# Add generated text to the list of messages
    add_assistant_message(messages, answer)

# Print the generated text
    print("---")
    print(answer)
    print("---")
# Out:
# > What is cloud computing?
# ---
# # Cloud Computing
#
# Cloud computing is the delivery of **computing services over the internet** ("the cloud") rather than using local hardware or servers.
#
# ## Core Idea
# Instead of owning and maintaining physical infrastructure, you access computing resources **on-demand** from a provider.
#
# ## Main Service Types
# | Type | What It Provides | Example |
# |------|-----------------|---------|
# | **IaaS** (Infrastructure as a Service) | Servers, storage, networking | AWS, Azure |
# | **PaaS** (Platform as a Service) | Development tools, runtime environments | Google App Engine |
# | **SaaS** (Software as a Service) | Ready-to-use applications | Gmail, Dropbox |
#
# ## Key Characteristics
# - **On-demand access** – use resources when needed
# - **Scalability** – easily scale up or down
# - **Pay-as-you-go** – pay only for what you use
# - **Remote access** – accessible from anywhere
# - **Shared resources** – infrastructure shared among users
#
# ## Common Uses
# - Data storage and backup
# - Hosting websites and applications
# - Streaming services
# - Collaboration tools
# - Machine learning and analytics
#
# ## Major Providers
# - Amazon Web Services (AWS)
# - Microsoft Azure
# - Google Cloud Platform
#
# ## Simple Analogy
# Think of it like **electricity** — you don't build your own power plant; you just plug in and pay for what you use.
#
# Would you like to know more about any specific aspect?
# ---
# > Where to knowing this is useful?
# ---
# # Where Cloud Computing Knowledge is Useful
#
# ## Career Fields
#
# ### 💻 Information Technology
# - **Cloud Engineer/Architect** - designing cloud systems
# - **DevOps Engineer** - automating deployments
# - **System Administrator** - managing infrastructure
# - **Cybersecurity** - securing cloud environments
#
# ### 💼 Business & Management
# - **IT Manager** - making technology decisions
# - **Project Manager** - managing tech projects
# - **Business Analyst** - understanding technical systems
#
# ### 📊 Data & Analytics
# - **Data Scientist** - using cloud for data processing
# - **Data Engineer** - building data pipelines
# - **Machine Learning Engineer** - training AI models
#
# ### 🛠️ Software Development
# - **Web Developer** - hosting applications
# - **App Developer** - deploying mobile/web apps
# - **Backend Developer** - managing servers and databases
#
# ---
#
# ## Industries That Use It
# - Healthcare
# - Finance & Banking
# - Education
# - E-commerce
# - Entertainment/Streaming
# - Government
#
# ---
#
# ## Everyday Practical Uses
# - Managing your own website
# - Running a small business
# - Understanding your data privacy
# - Making informed tech purchases
#
# ---
#
# ## Key Point
# > Cloud computing is now **fundamental to almost every tech role** and increasingly important in **non-tech roles** too.
#
# Would you like guidance on **how to learn** cloud computing?
# ---
